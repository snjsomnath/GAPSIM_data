# %%
# Change directory to one level up to import the module
import os
os.chdir("..")

# %%
from tripsender.sequencer import process_activity_sequence
from tripsender.activity import Activity, ActivitySequence

# %%
process_activity_sequence()
# Out:
# c:\Users\ssanjay\AppData\Local\Continuum\anaconda3\envs\tripsender\lib\site-packages\IPython\core\interactiveshell.py:3445: DtypeWarning: Columns (34,41,42,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   if await self.run_code(code, result, async_=asy):

# %%
list_of_person_dicts = []
for activity_sequence in ActivitySequence.instances:
    list_of_person_dicts.append(activity_sequence.sampled_person)

# %%
list_of_person_dicts
# Out:
# [{'id': 5.0,
#   'sex': 'Män',
#   'age_group': '35-44',
#   'house_type': 'Apartment',
#   'child_count': 0.0,
#   'adult_count': 2.0,
#   'household_type': 'Couple',
#   'car_count': 1.0},
#  {'id': 11.0,
#   'sex': 'Kvinnor',
#   'age_group': '75+',
#   'house_type': 'Apartment',
#   'child_count': 0.0,
#   'adult_count': 1.0,
#   'household_type': 'Single',
#   'car_count': 1.0},
#  {'id': 13.0,
#   'sex': 'Män',
#   'age_group': '16-24',
#   'house_type': 'Apartment',
#   'child_count': 0.0,
#   'adult_count': 2.0,
#   'household_type': 'Couple',
#   'car_count': 0.0},
#  {'id': 20.0,
#   'sex': 'Kvinnor',
#   'age_group': '55-64',
#   'house_type': 'Apartment',
#   'child_count': 0.0,
#   'adult_count': 2.0,
#   'household_type': 'Couple',
#   'car_count': 1.0},
#  {'id': 33.0,
#   'sex': 'Kvinnor',
#   'age_group': '75+',
#   'house_type': 'Villa',
#   'child_count': 0.0,
#   'adult_count': 2.0,
#   'household_type': 'Couple',
#   'car_count': 1.0},
#  {'id': 34.0,
# ...
